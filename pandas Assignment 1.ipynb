# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\cleaned_all_phones.csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1512.000000  1512.000000  1512.000000  1512.000000  1512.000000
# mean      6.422460  4389.798942     6.683862   187.636243   109.164683
# std       0.477043   784.607022     2.701433    26.200115    74.436484
# min       3.800000  1821.000000     1.000000   130.000000     1.000000
# 25%       6.300000  4000.000000     4.000000   175.000000    64.000000
# 50%       6.500000  4500.000000     8.000000   187.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   197.250000   128.000000
# max      10.400000  7250.000000    24.000000   500.000000   512.000000
#
#         price(USD)
# count  1512.000000
# mean    337.847036
# std     266.740821
# min      40.000000
# 25%     179.997500
# 50%     260.000000
# 75%     400.000000
# max    2300.000000

# %%
#1. how many unique mobile brands are there
len(data["brand"].unique())
# Out:
# 13

# %%
#2. what is the average RAM in all the mobiles
data["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %%
#3. which phone name is having the max battery
data.loc[data["battery"]==data["battery"].max(),["phone_name","battery"]]
# Out:
#     phone_name  battery
# 573         V6     7250

# %%
#4. which phone name is having the max battery
data.loc[data["battery"]==data["battery"].min(),["phone_name","battery"]]
# Out:
#            phone_name  battery
# 62           iPhone 8     1821
# 536  iPhone SE (2020)     1821

# %%
#5. what is the max battery given by Huawei
data.loc[((data["brand"]=="Huawei")& (data["battery"]==data["battery"])),["battery"]].max()
# Out:
# battery    7000
# dtype: int64

# %%
#6. which ph brand has the min RAM
data.loc[data["ram(GB)"]==data["ram(GB)"].min(),["brand","ram(GB)"]]
# Out:
#        brand  ram(GB)
# 27    Huawei        1
# 28   Samsung        1
# 69   Samsung        1
# 133   Huawei        1
# 182  Samsung        1
# 230  Samsung        1
# 236   Huawei        1
# 244   Xiaomi        1
# 304  Samsung        1
# 363       LG        1
# 550  Samsung        1

# %%
#7. which is the oldest phone announced also with dates of announcements
data.loc[data["announcement_date"]==data["announcement_date"].min(),["phone_name","announcement_date"]]
# Out:
#      phone_name announcement_date
# 0  Y6II Compact        2016-09-01

# %%
#8. how many phones has android 7.0 as their operating system
data.loc[data["os"]=="Android 7.0",["phone_name"]].count()
# Out:
# phone_name    33
# dtype: int64

# %%
#9. which brand is having least no.of phones produced
data.loc[data["phone_name"]==data["phone_name"].count(),["phone_name"]]
# Out:
# Empty DataFrame
# Columns: [phone_name]
# Index: []

# %%
#10. give me phone name and brand name having the costliest phone
data.loc[data["price(USD)"]==data["phone_name"].max(),["phone_name","brand","price(USD)"]]
# Out:
# Empty DataFrame
# Columns: [phone_name, brand, price(USD)]
# Index: []

# %%
#11. give me phone name and brand name having the cheapest phone
data.loc[data["price(USD)"]==data["phone_name"].min(),["phone_name","brand","price(USD)"]]
# Out:
# Empty DataFrame
# Columns: [phone_name, brand, price(USD)]
# Index: []

# %%
#12. how many phones supports (i)4k (ii)8k video (iii)2k video
data.loc[data["video_4K"]==True,["phone_name"]].count()
# Out:
# phone_name    801
# dtype: int64

# %%
data.loc[data["video_8K"]==True,["phone_name"]].count()
# Out:
# phone_name    86
# dtype: int64
